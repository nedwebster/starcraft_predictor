# %% [markdown]
# # Starcraft Predictor API

# %%
from starcraft_predictor import load_scorer

# %% [markdown]
# The user can import the `load_scorer` function, and use it to load a `ReplayScorer` object which contains a pre-trained ML model.

# %%
replay_scorer = load_scorer()

# %%
_ = replay_scorer.score_replay(replay_path="../example_data/example_replay.SC2Replay")
